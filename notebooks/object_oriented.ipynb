# %% [markdown]
# <a href="https://colab.research.google.com/github/oramirezperera/matplotlib_seaborn_practice/blob/main/notebooks/object_oriented.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,5,11)
y = x**2

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.5,0.9])
axes.plot(x,y)
fig.show()

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.9])
axes2 = fig.add_axes([0.2,0.6,0.4,0.3])
axes.plot(x,y)
axes2.plot(y,x,'g')
axes2.set_facecolor('gray')
fig.show()
